# %%
catalog.list()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 catalog.list()                                                                               │
# │   2                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'catalog' is not defined

# %%
In [2]: %reload_kedro
# Out:
# [04/07/24 18:05:18] INFO     Resolved project path as:                                              ]8;id=39722;file:///home/robinlhk/miniconda3/envs/ocp7-kedro-env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=422516;file:///home/robinlhk/miniconda3/envs/ocp7-kedro-env/lib/python3.10/site-packages/kedro/ipython/__init__.py#164\164]8;;\
#                              /home/robinlhk/Documents/Github_projects/ocp7-scoring-model-cloud.
#                              To set a different path, run '%reload_kedro <project_root>'
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/robinlhk/miniconda3/envs/ocp7-kedro-env/lib/python3.10/site-packages/kedro/io/core.py:152  │
# │ in from_config                                                                                   │
# │                                                                                                  │
# ...
